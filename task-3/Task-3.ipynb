# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "data/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 2s - 151ms/step - accuracy: 0.1200 - loss: 2.9528 - val_accuracy: 0.1333 - val_loss: 2.6560
# Epoch 2/30
# 13/13 - 0s - 11ms/step - accuracy: 0.3600 - loss: 2.0334 - val_accuracy: 0.1333 - val_loss: 2.4164
# Epoch 3/30
# 13/13 - 0s - 11ms/step - accuracy: 0.5600 - loss: 1.7406 - val_accuracy: 0.2667 - val_loss: 2.2066
# Epoch 4/30
# 13/13 - 0s - 10ms/step - accuracy: 0.6000 - loss: 1.4247 - val_accuracy: 0.3000 - val_loss: 2.0536
# Epoch 5/30
# 13/13 - 0s - 10ms/step - accuracy: 0.7800 - loss: 1.1823 - val_accuracy: 0.3333 - val_loss: 1.9199
# Epoch 6/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9000 - loss: 0.9939 - val_accuracy: 0.4000 - val_loss: 1.8153
# Epoch 7/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9200 - loss: 0.8388 - val_accuracy: 0.4333 - val_loss: 1.7276
# Epoch 8/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9400 - loss: 0.7144 - val_accuracy: 0.4667 - val_loss: 1.6527
# Epoch 9/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9400 - loss: 0.6120 - val_accuracy: 0.5000 - val_loss: 1.5909
# Epoch 10/30
# 13/13 - 0s - 10ms/step - accuracy: 0.9600 - loss: 0.5285 - val_accuracy: 0.5333 - val_loss: 1.5384
# Epoch 11/30
# 13/13 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.4598 - val_accuracy: 0.6000 - val_loss: 1.4936
# Epoch 12/30
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.4026 - val_accuracy: 0.6333 - val_loss: 1.4552
# Epoch 13/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.3548 - val_accuracy: 0.6333 - val_loss: 1.4223
# Epoch 14/30
# 13/13 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.3148 - val_accuracy: 0.6333 - val_loss: 1.3939
# Epoch 15/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.2809 - val_accuracy: 0.6333 - val_loss: 1.3692
# Epoch 16/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.2522 - val_accuracy: 0.6333 - val_loss: 1.3475
# Epoch 17/30
# 13/13 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.2277 - val_accuracy: 0.6333 - val_loss: 1.3284
# Epoch 18/30
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2066 - val_accuracy: 0.6333 - val_loss: 1.3115
# Epoch 19/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1884 - val_accuracy: 0.6333 - val_loss: 1.2964
# Epoch 20/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1726 - val_accuracy: 0.6333 - val_loss: 1.2828
# Epoch 21/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1588 - val_accuracy: 0.6333 - val_loss: 1.2705
# Epoch 22/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1466 - val_accuracy: 0.6667 - val_loss: 1.2594
# Epoch 23/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1359 - val_accuracy: 0.6667 - val_loss: 1.2492
# Epoch 24/30
# 13/13 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.1263 - val_accuracy: 0.6667 - val_loss: 1.2399
# Epoch 25/30
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1178 - val_accuracy: 0.6667 - val_loss: 1.2313
# Epoch 26/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1102 - val_accuracy: 0.6667 - val_loss: 1.2234
# Epoch 27/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.1033 - val_accuracy: 0.6667 - val_loss: 1.2161
# Epoch 28/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0971 - val_accuracy: 0.6667 - val_loss: 1.2093
# Epoch 29/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 0.6667 - val_loss: 1.2030
# Epoch 30/30
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0863 - val_accuracy: 0.6667 - val_loss: 1.1970

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 110ms/step - accuracy: 0.0800 - loss: 2.4423 - val_accuracy: 0.2000 - val_loss: 2.3161
# Epoch 2/30
# 13/13 - 0s - 11ms/step - accuracy: 0.3200 - loss: 2.0453 - val_accuracy: 0.2333 - val_loss: 2.1606
# Epoch 3/30
# 13/13 - 0s - 10ms/step - accuracy: 0.5200 - loss: 1.7599 - val_accuracy: 0.3000 - val_loss: 2.0101
# Epoch 4/30
# 13/13 - 0s - 9ms/step - accuracy: 0.6800 - loss: 1.5191 - val_accuracy: 0.4333 - val_loss: 1.8695
# Epoch 5/30
# 13/13 - 0s - 9ms/step - accuracy: 0.7800 - loss: 1.3142 - val_accuracy: 0.4333 - val_loss: 1.7467
# Epoch 6/30
# 13/13 - 0s - 8ms/step - accuracy: 0.8800 - loss: 1.1413 - val_accuracy: 0.4667 - val_loss: 1.6440
# Epoch 7/30
# 13/13 - 0s - 8ms/step - accuracy: 0.9200 - loss: 0.9959 - val_accuracy: 0.5000 - val_loss: 1.5591
# Epoch 8/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.8736 - val_accuracy: 0.5333 - val_loss: 1.4881
# Epoch 9/30
# 13/13 - 0s - 8ms/step - accuracy: 0.9400 - loss: 0.7704 - val_accuracy: 0.5667 - val_loss: 1.4282
# Epoch 10/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9600 - loss: 0.6830 - val_accuracy: 0.5667 - val_loss: 1.3772
# Epoch 11/30
# 13/13 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.6087 - val_accuracy: 0.6333 - val_loss: 1.3335
# Epoch 12/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.5452 - val_accuracy: 0.6667 - val_loss: 1.2958
# Epoch 13/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.4906 - val_accuracy: 0.6667 - val_loss: 1.2632
# Epoch 14/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.4435 - val_accuracy: 0.6667 - val_loss: 1.2348
# Epoch 15/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.4026 - val_accuracy: 0.6667 - val_loss: 1.2101
# Epoch 16/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3670 - val_accuracy: 0.7000 - val_loss: 1.1883
# Epoch 17/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3358 - val_accuracy: 0.7000 - val_loss: 1.1692
# Epoch 18/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3083 - val_accuracy: 0.7000 - val_loss: 1.1521
# Epoch 19/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2840 - val_accuracy: 0.7000 - val_loss: 1.1370
# Epoch 20/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2624 - val_accuracy: 0.7000 - val_loss: 1.1234
# Epoch 21/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.2432 - val_accuracy: 0.7000 - val_loss: 1.1112
# Epoch 22/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2261 - val_accuracy: 0.7000 - val_loss: 1.1002
# Epoch 23/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.2107 - val_accuracy: 0.7333 - val_loss: 1.0903
# Epoch 24/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1968 - val_accuracy: 0.7333 - val_loss: 1.0813
# Epoch 25/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1843 - val_accuracy: 0.7333 - val_loss: 1.0731
# Epoch 26/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1730 - val_accuracy: 0.7333 - val_loss: 1.0656
# Epoch 27/30
# 13/13 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1627 - val_accuracy: 0.7333 - val_loss: 1.0587
# Epoch 28/30
# 13/13 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1533 - val_accuracy: 0.7667 - val_loss: 1.0524
# Epoch 29/30
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1447 - val_accuracy: 0.7667 - val_loss: 1.0466
# Epoch 30/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1369 - val_accuracy: 0.7667 - val_loss: 1.0413

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
